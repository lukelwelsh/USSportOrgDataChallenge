# %%
import obj
import women_sim
import pandas as pd
import numpy as np
import os
import warnings
from scipy.stats import norm
import itertools
warnings.filterwarnings('ignore')
import concurrent.futures
import time

sims = pd.read_csv('w_sims.csv')

# %%
# Getting all Combos of USA Women --> combos

us_women = obj.w_country('USA').ath_perf
low = {}
top_5_AA_US = dict(sorted(us_women.items(), key=lambda item: sum(item[1]['mean']), reverse = True)[:5])
for ath in top_5_AA_US:
    for app in top_5_AA_US[ath].itertuples():
        if app.Index not in low:
            low[app.Index] = [app.mean]
        else:
            low[app.Index].append(app.mean)
low_4 = {k: sorted(v)[2] for k, v in low.items()}

considered_us_women = set()
for ath in us_women:
    for app in us_women[ath].itertuples():
        if app.mean >= low_4[app.Index]:
            considered_us_women.add(ath)
combos = list(itertools.combinations(list(considered_us_women), 5)) # len() =  CHOOSE 5
# women are considered for lineup combinations if, in ANY apparatus, their average score is better than or equal to 3 of the top 5 All Around US women

# %%
# function to simulate a qualifying round for a given combo of USA men

USA_women_performances = obj.w_country('USA').ath_perf
def set_lineup_from_names(name_combo):
    country_comp = {'FX': [], 'BB': [], 'UB': [], 'VT': []}
    country_mean_scores = {'FX': [], 'BB': [], 'UB': [], 'VT': []}
    score_range = np.arange(12, 17, 0.001)
    for gymnast in name_combo:
        for apparatus in USA_women_performances[gymnast].itertuples():
            if len(country_comp[apparatus.Index]) < 4:
                dist = norm.cdf(score_range, loc=apparatus.mean, scale=apparatus.std_dev)
                country_comp[apparatus.Index].append((apparatus.mean, apparatus.std_dev, dist, gymnast, 'USA'))
                country_mean_scores[apparatus.Index].append(apparatus.mean)

            elif apparatus.mean > min(country_mean_scores[apparatus.Index]):
                dist = norm.cdf(score_range, loc=apparatus.mean, scale=apparatus.std_dev)
                country_comp[apparatus.Index].append((apparatus.mean, apparatus.std_dev, dist, gymnast, 'USA'))
                for i, p in enumerate(country_comp[apparatus.Index]):
                    if min(country_mean_scores[apparatus.Index]) == p[0]:
                        country_comp[apparatus.Index].pop(i)       
    qual_scores = {}
    for apparatus in country_comp: # Run Qualifying Rounds
        for athlete in country_comp[apparatus]:
            qual_scores[athlete[3] + '-' + athlete[4] + '_' + apparatus] = np.random.normal(athlete[0], athlete[1], 100)
    return pd.DataFrame(qual_scores)

# %%
t = time.time()
sim_results = []
def simulate_simulation(simulation_id):
    if simulation_id % 10 in list(range(os.cpu_count())):
        print(simulation_id, time.time() - t)
        pd.DataFrame(sim_results).to_csv(f'results_{simulation_id%10}.csv')
    us_sims = set_lineup_from_names(combos[simulation_id])
    full_competition = pd.concat([sims, us_sims], axis = 1)
    final_medals = women_sim.qual_to_medals(full_competition)
    medals = {'gymnasts': combos[simulation_id]}
    for comp_type in final_medals:
        for medal_type in final_medals[comp_type]['USA']:
            medals[comp_type + ' ' + medal_type] = final_medals[comp_type]['USA'][medal_type]
    sim_results.append(medals)
    return medals

# Number of simulations
num_simulations = len(combos)

# Number of parallel processes (cores)
num_cores = os.cpu_count()

# Create a list of simulation IDs
simulation_ids = list(range(num_simulations))

# Function to run simulations concurrently
def run_simulations_parallel(simulation_ids):
    with concurrent.futures.ProcessPoolExecutor(max_workers=num_cores) as executor:
        # Using executor.map to parallelize the simulations
        results = list(executor.map(simulate_simulation, simulation_ids))

    return results

# Run simulations concurrently
simulation_results = run_simulations_parallel(simulation_ids)

# Print the results (replace with actual processing of results)
print("Simulation Results:", simulation_results)
print(t - time.time())
# Out:
# 0 0.052973031997680664
# 2 3 0.05845499038696289
# 0.0602059364318847661
# 0.058087825775146484
# 10 208.6139430999756
# 11 208.71240305900574
# 12 312.8997769355774
# 13 312.9770357608795
# 20 521.8007814884186
# 21 522.3140895366669
# 22 522.5440261363983
# 23 523.0639185905457
# 30 732.6919982433319
# 31 732.7216126918793
# 32 835.3720774650574
# 33 837.1143937110901
# 40 1043.3010954856873
# 41 1045.6079270839691
# 42 1046.5276882648468
# 43 1046.8142523765564
# 50 1255.812825679779
# 51 1256.1710977554321
# 52 1356.9529345035553
# 53 1359.4476466178894
# 60 1565.7055909633636
# 61 1568.5788462162018
# 62 1569.7381393909454
# 63 1569.8824508190155
# 70 1778.5949811935425
# 71 1779.78249168396
# 72 1879.4951133728027
# 73 1881.776701927185
# 80 2088.2287242412567
# 81 2090.5092182159424
# 82 2092.224947452545
# 83 2093.553364276886
# 90 2301.144958972931
# 91 2303.033017873764
# 92 2401.4574048519135
# 93 2404.3043682575226
# 100 2610.7758843898773
# 101 2613.024592399597
# 102 2614.2062180042267
# 103 2616.8009464740753
# 110 2823.09330368042
# 111 2826.5161838531494
# 112 2924.8500604629517
# 113 2926.6125979423523
# 120 3133.1921331882477
# 121 3135.297879219055
# 122 3136.063131570816
# 123 3140.499856710434
# 130 3345.6171748638153
# 131 3350.111480474472
# 132 3445.829097509384
# 133 3448.134735107422
# 140 3654.36856842041
# 141 3657.9583611488342
# 142 3659.044550895691
# 143 3664.4990961551666
# 150 3868.8470039367676
# 151 3874.1838393211365
# 152 3968.8253605365753
# 153 3972.420798063278
# 160 4178.344377040863
# 161 4182.696993112564
# 162 4183.473520040512
# 163 4190.023265838623
# 170 4395.100613832474
# 171 4401.4150133132935
# 172 4493.846040010452
# 173 4498.246162414551
# 180 4703.077181100845
# 181 4706.839039325714
# 182 4709.4167194366455
# 183 4714.337116241455
# 190 4918.868895769119
# 191 4923.997994422913
# 192 5016.731801509857
# 193 5020.766335010529
# 200 5226.95943903923
# 201 5230.96906542778
# 202 5233.474906206131
# 203 5237.60249209404
# 210 5442.702281236649
# 211 5447.745260953903
# 212 5540.233509302139
# 213 5546.007876157761
# 220 5749.3197367191315
# 221 5755.191743612289
# 222 5756.393483400345
# 223 5762.1095058918
# 230 5966.285130262375
# 231 5970.824146270752
# 232 6063.501336574554
# 233 6068.653792619705
# 240 6272.994580030441
# 241 6277.627194643021
# 242 6281.007291555405
# 243 6284.71685385704
# 250 6491.223795890808
# 251 6494.849595308304
# 252 6588.109902620316
# 253 6593.109397411346
# 260 6797.798795700073
# 261 6802.9380395412445
# 262 6806.241991281509
# 263 6809.70650267601
# 270 7015.213943243027
# 271 7018.941598653793
# 272 7111.880976438522
# 273 7116.478508234024
# 280 7321.32203745842
# 281 7325.609544754028
# 282 7329.060264825821
# 283 7334.13086438179
# 290 7539.246582984924
# 291 7544.2165558338165
# 292 7635.0702793598175
# 293 7639.728031635284
# 300 7844.5548396110535
# 301 7848.883024692535
# 302 7853.551478147507
# 303 7859.0891942977905
# 310 8063.029415369034
# 311 8069.294616699219
# 312 8158.527208566666
# 313 8162.9027943611145
# 320 8366.95307469368
# 321 8371.618552684784
# 322 8376.92443060875
# 323 8383.671959161758
# 330 8586.578668117523
# 331 8591.968292236328
# 332 8680.546719789505
# 333 8683.972703933716
# 340 8889.822060108185
# 341 8894.704406738281
# 342 8901.841181755066
# 343 8905.569721460342
# 350 9112.620212316513
# 351 9115.626053571701
# 352 9204.14403796196
# 353 9209.837064027786
# 360 9413.902044296265
# 361 9419.690603256226
# 362 9427.371186256409
# 363 9430.536129951477
# 370 9638.269678592682
# 371 9640.165270805359
# 372 9727.760299921036
# 373 9734.790271282196
# 380 9937.078001260757
# 381 9944.21837735176
# 382 9952.656758785248
# 383 9954.212126255035
# 390 10162.948783159256
# 391 10163.960952758789
# 392 10251.084350585938
# 393 10258.9379966259
# 400 10460.31500673294
# 401 10467.536191225052
# 402 10477.265365123749
# 403 10477.368342399597
# 410 10687.017372369766
# 411 10687.10523056984
# 412 10774.610092401505
# 413 10781.970379829407
# 420 10983.118547439575
# 421 10990.649785041809
# 422 11000.663807153702
# 423 11001.150332927704
# 430 11210.56315779686
# 431 11210.76928782463
# 432 11297.584554672241
# 433 11304.99375987053
# 440 11507.058012723923
# 441 11514.517978906631
# 442 11525.188664674759
# 443 11525.560547113419
# 450 11733.88549542427
# 451 11734.458800792694
# 452 11819.67194223404
# 453 11827.225932598114
# 460 12028.957499742508
# 461 12036.712912797928
# Simulation Results: [{'gymnasts': ('Simone BILES', 'Shilese JONES', 'eMjae FRAZIER', 'Sunisa LEE', 'Zoe MILLER'), 'Apparatus gold': 20713, 'Apparatus silver': 9296, 'Apparatus bronze': 8735, 'Indv. AA gold': 9404, 'Indv. AA silver': 3052, 'Indv. AA bronze': 3555, 'Team AA gold': 9470, 'Team AA silver': 464, 'Team AA bronze': 53}, {'gymnasts': ('Simone BILES', 'Shilese JONES', 'eMjae FRAZIER', 'Sunisa LEE', 'Leanne WONG'), 'Apparatus gold': 20138, 'Apparatus silver': 9210, 'Apparatus bronze': 8910, 'Indv. AA gold': 9404, 'Indv. AA silver': 3052, 'Indv. AA bronze': 3555, 'Team AA gold': 9680, 'Team AA silver': 299, 'Team AA bronze': 18}, {'gymnasts': ('Simone BILES', 'Shilese JONES', 'eMjae FRAZIER', 'Sunisa LEE', 'Jordan CHILES'), 'Apparatus gold': 20138, 'Apparatus silver': 9981, 'Apparatus bronze': 10488, 'Indv. AA gold': 9404, 'Indv. AA silver': 3052, 'Indv. AA bronze': 3555, 'Team AA gold': 9751, 'Team AA silver': 232, 'Team AA bronze': 14}, {'gymnasts': ('Simone BILES', 'Shilese JONES', 'eMjae FRAZIER', 'Sunisa LEE', 'Skye BLAKELY'), 'Apparatus gold': 20119, 'Apparatus silver': 9461, 'Apparatus bronze': 9482, 'Indv. AA gold': 9399, 'Indv. AA silver': 1168, 'Indv. AA bronze': 1656, 'Team AA gold': 9701, 'Team AA silver': 283, 'Team AA bronze': 12}, {'gymnasts': ('Simone BILES', 'Shilese JONES', 'eMjae FRAZIER', 'Sunisa LEE', 'Kaliya LINCOLN'), 'Apparatus gold': 20141, 'Apparatus silver': 10933, 'Apparatus bronze': 10911, 'Indv. AA gold': 9438, 'Indv. AA silver': 3061, 'Indv. AA bronze': 3500, 'Team AA gold': 8667, 'Team AA silver': 1077, 'Team AA bronze': 195}, {'gymnasts': ('Simone BILES', 'Shilese JONES', 'eMjae FRAZIER', 'Sunisa LEE', 'Jade CAREY'), 'Apparatus gold': 20377, 'Apparatus silver': 12125, 'Apparatus bronze': 11688, 'Indv. AA gold': 9438, 'Indv. AA silver': 3061, 'Indv. AA bronze': 3500, 'Team AA gold': 9681, 'Team AA silver': 300, 'Team AA bronze': 17}, {'gymnasts': ('Simone BILES', 'Shilese JONES', 'eMjae FRAZIER', 'Sunisa LEE', 'Konnor MCCLAIN'), 'Apparatus gold': 21388, 'Apparatus silver': 11632, 'Apparatus bronze': 11077, 'Indv. AA gold': 9369, 'Indv. AA silver': 2739, 'Indv. AA bronze': 3463, 'Team AA gold': 9815, 'Team AA silver': 179, 'Team AA bronze': 6}, {'gymnasts': ('Simone BILES', 'Shilese JONES', 'eMjae FRAZIER', 'Zoe MILLER', 'Leanne WONG'), 'Apparatus gold': 20413, 'Apparatus silver': 9669, 'Apparatus bronze': 8982, 'Indv. AA gold': 9349, 'Indv. AA silver': 3193, 'Indv. AA bronze': 3926, 'Team AA gold': 9161, 'Team AA silver': 727, 'Team AA bronze': 94}, {'gymnasts': ('Simone BILES', 'Shilese JONES', 'eMjae FRAZIER', 'Zoe MILLER', 'Jordan CHILES'), 'Apparatus gold': 20585, 'Apparatus silver': 10603, 'Apparatus bronze': 10977, 'Indv. AA gold': 9359, 'Indv. AA silver': 3260, 'Indv. AA bronze': 4086, 'Team AA gold': 9397, 'Team AA silver': 525, 'Team AA bronze': 63}, {'gymnasts': ('Simone BILES', 'Shilese JONES', 'eMjae FRAZIER', 'Zoe MILLER', 'Skye BLAKELY'), 'Apparatus gold': 20676, 'Apparatus silver': 10002, 'Apparatus bronze': 9943, 'Indv. AA gold': 9393, 'Indv. AA silver': 3316, 'Indv. AA bronze': 4079, 'Team AA gold': 9322, 'Team AA silver': 580, 'Team AA bronze': 80}, {'gymnasts': ('Simone BILES', 'Shilese JONES', 'eMjae FRAZIER', 'Zoe MILLER', 'Kaliya LINCOLN'), 'Apparatus gold': 20730, 'Apparatus silver': 11129, 'Apparatus bronze': 11322, 'Indv. AA gold': 9377, 'Indv. AA silver': 3072, 'Indv. AA bronze': 3583, 'Team AA gold': 9271, 'Team AA silver': 612, 'Team AA bronze': 89}, {'gymnasts': ('Simone BILES', 'Shilese JONES', 'eMjae FRAZIER', 'Zoe MILLER', 'Jade CAREY'), 'Apparatus gold': 20793, 'Apparatus silver': 12292, 'Apparatus bronze': 12106, 'Indv. AA gold': 9360, 'Indv. AA silver': 3177, 'Indv. AA bronze': 3893, 'Team AA gold': 9517, 'Team AA silver': 439, 'Team AA bronze': 35}, {'gymnasts': ('Simone BILES', 'Shilese JONES', 'eMjae FRAZIER', 'Zoe MILLER', 'Konnor MCCLAIN'), 'Apparatus gold': 22125, 'Apparatus silver': 11746, 'Apparatus bronze': 11235, 'Indv. AA gold': 9357, 'Indv. AA ...
# -12110.550303697586

# %%
pd.DataFrame(simulation_results).to_csv('women_medal.csv')
